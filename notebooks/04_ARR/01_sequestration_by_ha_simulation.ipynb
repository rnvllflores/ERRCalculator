# %% [markdown]
# # Imports and Set-up

# %%
import sys
import pandas as pd

# %%
# Util imports
sys.path.append("../../")  # include parent directory
from src.settings import CSV_DATA_DIR

# %%
# Filepaths
seq_reference = CSV_DATA_DIR / "arr_growth" / "yoy-sequestration.csv"
output_fpath = CSV_DATA_DIR / "arr_growth" / "yoy-sequestration_per_ha.csv"

# %%
seq_per_tree = pd.read_csv(seq_reference)

# %%
seq_per_tree.columns
# Out:
# Index(['year', 'Dipterocarpus grandiflorus', 'Hopea plagata',
#        'Parashorea malaanonan', 'Shorea almon', 'Shorea contorta'],
#       dtype='object')

# %%
# variables
total_trees_per_hectare = 400
species_percentage = {
    "Dipterocarpus grandiflorus": 0.40,
    "Hopea plagata": 0.30,
    "Parashorea malaanonan": 0.30,
}
seq_per_ha = seq_per_tree.copy()
seq_per_ha.set_index("year", inplace=True)

# %%
# Filter the table to include only the species in the species_percentage dictionary
seq_per_ha = seq_per_ha[species_percentage.keys()]

# %%
# For each species, calculate the sequestration per hectare by multiplying the sequestration by the number of trees of that species
for species, percentage in species_percentage.items():
    # Calculate the number of trees for this species in the hectare
    num_trees_per_species = total_trees_per_hectare * percentage

    # Multiply the sequestration per year for each species by the number of trees per species
    seq_per_ha[species] = seq_per_ha[species] * num_trees_per_species

# Now sum across all species for each year to get the total sequestration per hectare per year
seq_per_ha["total_sequestration_per_hectare"] = seq_per_ha.sum(axis=1)

# %%
seq_per_ha
# Out:
#       Dipterocarpus grandiflorus  Hopea plagata  Parashorea malaanonan  \
# year
# 0                       0.000000       0.000000               0.000000
# 1                       0.001188       0.000854               0.000598
# 2                       0.007852       0.005645               0.003953
# 3                       0.020592       0.014804               0.010366
# 4                       0.039166       0.028158               0.019716
# 5                       0.063431       0.045602               0.031931
# 6                       0.093283       0.067063               0.046959
# 7                       0.128640       0.092483               0.064758
# 8                       0.169437       0.121812               0.085295
# 9                       0.215617       0.155012               0.108542
# 10                      0.267131       0.192047               0.134474
# 11                      0.323937       0.232886               0.163070
# 12                      0.385998       0.277503               0.194311
# 13                      0.453278       0.325872               0.228180
# 14                      0.525746       0.377971               0.264661
# 15                      0.603373       0.433779               0.303738
# 16                      0.686134       0.493278               0.345400
# 17                      0.774003       0.556449               0.389633
# 18                      0.866957       0.623276               0.436427
# 19                      0.964975       0.693744               0.485769
# 20                      1.068037       0.767837               0.537651
# 21                      1.176124       0.845543               0.592061
# 22                      1.289217       0.926849               0.648992
# 23                      1.407299       1.011741               0.708435
# 24                      1.530354       1.100208               0.770381
# 25                      1.658367       1.192240               0.834823
#
#       total_sequestration_per_hectare
# year
# 0                            0.000000
# 1                            0.002640
# 2                            0.017450
# 3                            0.045762
# 4                            0.087040
# 5                            0.140965
# 6                            0.207305
# 7                            0.285881
# 8                            0.376544
# 9                            0.479170
# 10                           0.593652
# 11                           0.719894
# 12                           0.857812
# 13                           1.007330
# 14                           1.168377
# 15                           1.340891
# 16                           1.524812
# 17                           1.720085
# 18                           1.926660
# 19                           2.144488
# 20                           2.373525
# 21                           2.613729
# 22                           2.865058
# 23                           3.127475
# 24                           3.400944
# 25                           3.685430

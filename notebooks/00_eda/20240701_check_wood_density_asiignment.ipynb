# %% [markdown]
# # Imports and Set-up

# %%
# Standard Imports
import sys
import os
import pandas as pd
import numpy as np

# Google Cloud Imports
import pandas_gbq

# %%
# Util imports
sys.path.append("../../")  # include parent directory
from src.settings import (
    DATA_DIR,
    GCP_PROJ_ID,
    CARBON_POOLS_OUTDIR,
    CARBON_STOCK_OUTDIR,
    SPECIES_LOOKUP_CSV,
)

# from src.biomass_equations import vmd0003_eq1

# %%
# Variables
TREES_CSV = CARBON_POOLS_OUTDIR / "trees.csv"
SAPLING_CSV = CARBON_POOLS_OUTDIR / "saplings_ntv_litter.csv"
PLOT_INFO_CSV = CARBON_POOLS_OUTDIR / "plot_info.csv"

# BigQuery Variables
DATASET_ID = "carbon_stock"
IF_EXISTS = "replace"

# %% [markdown]
# ## Load data

# %% [markdown]
# ### Trees data

# %%
if TREES_CSV.exists():
    trees = pd.read_csv(TREES_CSV)
else:
    query = f"""
    SELECT 
        * 
    FROM {GCP_PROJ_ID}.{DATASET_ID}.trees"""

    # Read the BigQuery table into a dataframe
    trees = pandas_gbq.read_gbq(query, project_id=GCP_PROJ_ID)
    trees.to_csv(TREES_CSV, index=False)

# %%
trees.rename(
    columns={"species_name": "code_species", "family_name": "code_family"}, inplace=True
)

# %%
trees.loc[trees["code_species"] == 999, "code_species"] = np.nan

# %%
trees.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6579 entries, 0 to 6578
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   unique_id     6579 non-null   object
#  1   nest          6579 non-null   int64
#  2   code_species  4993 non-null   float64
#  3   code_family   1330 non-null   float64
#  4   DBH           6579 non-null   float64
# dtypes: float64(3), int64(1), object(1)
# memory usage: 257.1+ KB

# %%
trees.head(2)
# Out:
#   unique_id  nest  code_species  code_family   DBH
# 0     308D2     2           NaN         25.0  10.8
# 1     308D2     2           NaN         25.0  17.3

# %% [markdown]
# ### Tree species

# %%
species = pd.read_csv(SPECIES_LOOKUP_CSV)

# %%
species.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 375 entries, 0 to 374
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   code_family      74 non-null     float64
#  1   family           74 non-null     object
#  2   scientific_name  375 non-null    object
#  3   local_name       375 non-null    object
#  4   code_species     375 non-null    int64
#  5   corrected_genus  375 non-null    object
#  6   wood_density     375 non-null    float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 20.6+ KB

# %%
species.head(2)
# Out:
#    code_family       family       scientific_name    local_name  code_species  \
# 0        999.0      Unknown     Litchi chinensis   Alupag - amo           193
# 1          1.0  Alangiaceae  Alangium javanicum          Putian            15
#
#   corrected_genus  wood_density
# 0          Litchi      0.608902
# 1        Alangium      0.608902

# %% [markdown]
# ## Add species using lookup table
#
# Wood density in this table was generated using [BIOMASS](https://www.rdocumentation.org/packages/BIOMASS/versions/2.1.11) library from R

# %%
merged_df = trees.merge(species, on="code_family", how="left")

# %%
# add family name based on lookup file
trees["family_name"] = merged_df["family"]

# %%
merged_df = trees.merge(species, on="code_species", how="left")

# %%
# add species name based on lookup file
trees["scientific_name"] = merged_df["scientific_name"]

# Add wood density based on scientific name
trees["wood_density"] = merged_df["wood_density"]

# %%
trees.fillna({"scientific_name": "Unknown", "family_name": "Unknown"}, inplace=True)

# %%
trees[(trees["code_species"].isna()) & (trees["code_family"])]
# Out:
#      unique_id  nest  code_species  code_family    DBH family_name  \
# 0        308D2     2           NaN         25.0   10.8    Fabaceae
# 1        308D2     2           NaN         25.0   17.3    Fabaceae
# 2        308D2     2           NaN         25.0   12.8    Fabaceae
# 3        308D2     2           NaN         25.0   28.1    Fabaceae
# 8        308B2     2           NaN         25.0   45.3     Unknown
# ...        ...   ...           ...          ...    ...         ...
# 6499     125C2     4           NaN         41.0  122.6     Unknown
# 6500     125C2     4           NaN         41.0   53.2     Unknown
# 6503     125A2     4           NaN         33.0   56.8     Unknown
# 6514     147B2     4           NaN         41.0   52.6     Unknown
# 6517     147D2     4           NaN         45.0   98.5     Unknown
#
#      scientific_name  wood_density
# 0            Unknown           NaN
# 1            Unknown           NaN
# 2            Unknown           NaN
# 3            Unknown           NaN
# 8            Unknown           NaN
# ...              ...           ...
# 6499         Unknown           NaN
# 6500         Unknown           NaN
# 6503         Unknown           NaN
# 6514         Unknown           NaN
# 6517         Unknown           NaN
#
# [924 rows x 8 columns]

# %%
unique_family_names = trees.loc[trees["code_species"].isna(), "family_name"].unique()
print(unique_family_names)
# Out:
# ['Fabaceae' 'Unknown' 'Dipterocarpaceae' 'Sapotaceae' 'Annonaceae']

# %%
trees.loc[
    (trees["code_family"].isna()) & (trees["code_species"].isna()),
]
# Out:
#      unique_id  nest  code_species  code_family    DBH family_name  \
# 4        308A2     2           NaN          NaN  18.70     Unknown
# 5        308A2     2           NaN          NaN  20.20     Unknown
# 6        308A2     2           NaN          NaN  14.70     Unknown
# 7        308A2     2           NaN          NaN  12.00     Unknown
# 32        22C2     2           NaN          NaN  20.40     Unknown
# ...        ...   ...           ...          ...    ...         ...
# 6466     399C2     4           NaN          NaN  84.90     Unknown
# 6470     399A2     4           NaN          NaN  62.00     Unknown
# 6472     203D2     4           NaN          NaN  69.55     Unknown
# 6530      80B2     4           NaN          NaN  58.30     Unknown
# 6533      80C2     4           NaN          NaN  88.30     Unknown
#
#      scientific_name  wood_density
# 4            Unknown           NaN
# 5            Unknown           NaN
# 6            Unknown           NaN
# 7            Unknown           NaN
# 32           Unknown           NaN
# ...              ...           ...
# 6466         Unknown           NaN
# 6470         Unknown           NaN
# 6472         Unknown           NaN
# 6530         Unknown           NaN
# 6533         Unknown           NaN
#
# [662 rows x 8 columns]

# %%
species[species["family"] == "Sapotaceae"]
# Out:
#     code_family      family       scientific_name local_name  code_species  \
# 62         62.0  Sapotaceae  Glebionis coronaria     Tungkao           152
#
#    corrected_genus  wood_density
# 62       Glebionis      0.714869

# %%
test = pd.read_csv("/Users/renflores/Documents/OneBase/data/csv/trees_processed_r.csv")

# %%
test[(test["species_name"] == "Unknown") & (test["family_name"] == "Unknown")]
# Out:
#      unique_ID  nest  team species_name family_name   DBH  slope  latitude  \
# 12       101A2     2     3      Unknown     Unknown  11.1     39  8.679330
# 13       101B2     3     3      Unknown     Unknown  30.0      8  8.679171
# 14       101C2     2     3      Unknown     Unknown  19.1     19  8.678523
# 17       101C2     2     3      Unknown     Unknown  29.0     19  8.678523
# 18       101C2     3     3      Unknown     Unknown  62.3     19  8.678523
# ...        ...   ...   ...          ...         ...   ...    ...       ...
# 6311      86B2     3     2      Unknown     Unknown  30.9     18  9.081891
# 6359      97B2     3     4      Unknown     Unknown  60.3     48  8.791470
# 6442      98C2     3     1      Unknown     Unknown  40.9     42       NaN
# 6457      98D2     4     1      Unknown     Unknown  57.5     32       NaN
# 6474      99B2     3     4      Unknown     Unknown  38.3     75  9.480592
#
#        longitude  lc_type lc_class genusCorr        WD          H  Strata  \
# 12    126.050833  f_plant       MX   Unknown  0.626893  13.253394       1
# 13    126.051785  f_plant       MX   Unknown  0.626893  22.779659       1
# 14    126.048674    f_nat      MCB   Unknown  0.626893  17.927968       1
# 17    126.048674    f_nat      MCB   Unknown  0.626893  22.395658       1
# 18    126.048674    f_nat      MCB   Unknown  0.626893  30.000000       1
# ...          ...      ...      ...       ...       ...        ...     ...
# 6311  126.031082    f_nat      MCB   Unknown  0.597575  23.115867       1
# 6359  125.993984    f_nat      MDF   Unknown  0.651367  30.000000       1
# 6442         NaN    f_nat      MCB   Unknown  0.626893  26.316477       1
# 6457         NaN    f_nat      MCB   Unknown  0.626893  29.951426       1
# 6474  125.694244    f_nat      MDF   Unknown  0.628101  25.571422       1
#
#            biomass  root_biomass
# 12      274.179798     65.803151
# 13     3239.518939    777.484545
# 14     1062.177730    254.922655
# 17     2982.184688    715.724325
# 18    17647.563609   4235.415266
# ...            ...           ...
# 6311   3322.366626    797.367990
# 6359  17189.233220   4125.415973
# 6442   6829.673266   1639.121584
# 6457  15067.071829   3616.097239
# 6474   5852.784226   1404.668214
#
# [699 rows x 17 columns]

# %%
unknown_wood_density = test[
    (test["species_name"] == "Unknown") & (test["family_name"] == "Unknown")
]["WD"].unique()
print(unknown_wood_density)
# Out:
# [0.62689306 0.63654755 0.58324631 0.56415561 0.65374774 0.71276048
#  0.61345774 0.76557815 0.65994282 0.6296433  0.70241661 0.68340839
#  0.6662754  0.57938183 0.67751888 0.64848263 0.64371242 0.37244234
#  0.63275243 0.61081898 0.44770306 0.5188693  0.48636364 0.70101373
#  0.66824248 0.45499492 0.60090105 0.6562678  0.64183324 0.61621167
#  0.56569511 0.60613125 0.56534708 0.66997691 0.65125871 0.61459908
#  0.6429952  0.59757549 0.65136686 0.62810107]
